# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniKia/Fearless/blob/main/Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cell 1: Clone your repository
# !git clone https://github.com/DaniKia/Fearless.git
# %cd Fearless
# Out:
# Cloning into 'Fearless'...
# remote: Enumerating objects: 64, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 64 (delta 37), reused 60 (delta 33), pack-reused 0 (from 0)
# Receiving objects: 100% (64/64), 80.90 KiB | 2.89 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# /content/Fearless/Fearless/Fearless/Fearless/Fearless/Fearless

# %%
# Cell 2: Mount Google Drive to access your dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Cell 3: Install dependencies
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 13.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 63.1 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=ba9026d2a7c6ede8694684e2ea3dad97cfa978ff4a4d347a1f6f4387d7e49be1
#   Stored in directory: /root/.cache/pip/wheels/61/d2/20/09ec9bef734d126cba375b15898010b6cc28578d8afdde5869
# Successfully built openai-whisper
# ...

# %%
# Cell 4: Run the pipeline - Process 5 files from Dev set
# !python main.py --file fsc_p3_ASR_track2_dev_0012.wav
# Out:
# ...
# ASR Pipeline with Whisper
# ...
# Phase: Phase3
# Dataset: Dev
# Whisper Model: tiny.en
# ...
# Detected Colab environment
# Google Drive already mounted
#
# Audio directory: /content/drive/MyDrive/Fearless_Steps_Challenge_Phase3/FSC_P3_Train_Dev/Audio/Segments/ASR_track2/Dev
# Transcript directory: /content/drive/MyDrive/Fearless_Steps_Challenge_Phase3/FSC_P3_Train_Dev/Transcripts/ASR_track2/Dev
# Loaded 9203 transcripts from Dev dataset
# Loading Whisper model: tiny.en...
# 100%|██████████████████████████████████████| 72.1M/72.1M [00:00<00:00, 176MiB/s]
# Model loaded successfully
# Transcribing: /content/drive/MyDrive/Fearless_Steps_Challenge_Phase3/FSC_P3_Train_Dev/Audio/Segments/ASR_track2/Dev/fsc_p3_ASR_track2_dev_0012.wav
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 100% 342/342 [00:07<00:00, 44.63frames/s]
#
# ...
